# %% [markdown]
# 19L-2313
# 18L-1395
# 19L-2258

# %%
import pandas as pd
import numpy as np
import random
import copy

# %%
data=pd.read_csv("TT Data one.csv")

# %%
print(data)

# %%
data.shape

# %%
Total_courses=data["CID"]

# %%
Total_courses

# %%
from collections import Counter
print(Counter(Total_courses))

# %%
print(len(Total_courses))

# %%
G1=data["G1"]

# %%
G2=data["G2"]

# %%
G1=np.array(G1)

# %%
G2=np.array(G2)

# %%
CID=np.array(Total_courses)

# %%
classrooms=25
Slots=9
EachSoltMinute=60

# %%
Data1=[]
i=0
for i in range(0,len(CID)):
  Data1.append((CID[i],G1[i]))

# %%
Data1

# %%
Data2=[]
j=0
for j in range(0,len(CID)):
  Data2.append((0,CID[j],G2[j]))

# %%
Data2

# %%
Total_data=Data1+Data2

# %%
len(Total_data)

# %%
import random

# %%
Total_data

# %%
Temp1=[]
row1=[]
Temp2=[]
row2=[]
for i in range(0,25):
  for j in range(0,9):
    if(len(Total_data)!=0):
      row1.append(Total_data.pop())
      row2.append(Total_data.pop())
    else:
      row1.append(0)
      row2.append(0)
  row1=[]
  row2=[]
  Temp1.append(row1)
  Temp2.append(row2)
MondaySchedule=np.array(Temp1)
TuesdaySchedule=np.array(Temp2)

# %%
MondaySchedule
# Out:
# array([list([(29, 87), (17, 86), (6, 85), (56, 84), (172, 83), (88, 83), (137, 82), (104, 80), (66, 78)]),
#        list([(103, 77), (100, 76), (98, 75), (11, 73), (9, 73), (93, 71), (65, 69), (48, 68), (62, 67)]),
#        list([(14, 66), (12, 66), (39, 64), (163, 63), (45, 62), (25, 61), (154, 59), (46, 57), (18, 56)]),
#        list([(91, 55), (78, 54), (63, 53), (76, 52), (107, 51), (135, 50), (175, 49), (49, 47), (125, 46)]),
#        list([(52, 45), (162, 44), (126, 42), (72, 42), (149, 41), (23, 39), (139, 38), (54, 37), (4, 36)]),
#        list([(159, 36), (156, 34), (153, 33), (19, 32), (147, 31), (34, 30), (130, 29), (166, 28), (133, 28)]),
#        list([(167, 26), (83, 26), (74, 25), (37, 23), (33, 22), (113, 21), (89, 20), (184, 19), (1, 19)]),
#        list([(111, 18), (151, 17), (97, 16), (95, 16), (121, 15), (168, 14), (79, 14), (186, 13), (183, 12)]),
#        list([(158, 11), (40, 10), (181, 9), (108, 9), (185, 7), (7, 7), (188, 6), (127, 5), (171, 4)]),
# ...

# %% [markdown]
# Initial Population for Monday is MondaySchedule &
# Initial Population for Tuesday is TuesdaySchedule

# %%
MondaySchedule[0]
# Out:
# [(29, 87),
#  (17, 86),
#  (6, 85),
#  (56, 84),
#  (172, 83),
#  (88, 83),
#  (137, 82),
#  (104, 80),
#  (66, 78)]

# %%
TuesdaySchedule[0]
# Out:
# [(28, 86),
#  (16, 86),
#  (5, 85),
#  (55, 84),
#  (146, 83),
#  (138, 82),
#  (24, 81),
#  (173, 79),
#  (161, 77)]

# %%
def FitnessValue(Schedule):
  n=len(Schedule)
  for i in range (n)
# Out:
#   File "<ipython-input-32-3564a7be24fd>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
def fsort(population):
    for i in range(len(population)):
        for j in range(i + 1, len(population)):
            if FitnessValue(population[i]) < FitnessValue(population[j]):
                population[i], population[j] = population[j], population[i]
