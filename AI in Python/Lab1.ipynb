# %%
print("Hello World!")
a=["abc","def","ghi"]
x=2
y=9
z=x/y
print("Z is :",z)
for i in a:
  print(i)
# Out:
# Hello World!
# Z is : 0
# abc
# def
# ghi

# %%
a=5
b=6
if a>=b:
  print(a)
else:
  print(b)
# Out:
# 6

# %%
a="3.5"
b='2'
print(float(a)+int(b))
# Out:
# 5.5

# %%
s="abcde"
r=""
for i in range(0,len(s)):
  print(s[-1-i])
  r=r+s[-1-i]
print(r)
# Out:
# e
# d
# c
# b
# a
# edcba
