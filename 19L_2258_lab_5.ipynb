# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("Employees_Absenteeism.csv",sep=',')
#type(df)
#df.head()
#df.tail()
print(df.shape)  #printing rows x cols
print(df.info)   #printing headers and datatype
#df.describe()
#df.Age.unique()
#df.Age.value_counts()
#df.columns.values
#df.corr()
#sns.heatmap(df.isnull(),cbar=False,yticklabels=False,cmap = 'viridis')
# plt.figure(figsize=(6,3))
# sns.heatmap(df.corr(),cmap='Blues',annot=False)
###############################################
# k = 12 #number of variables for heatmap
# cols = df.corr().nlargest(k, 'Age')['Age'].index
# cm = df[cols].corr()
# plt.figure(figsize=(10,6))
# sns.heatmap(cm, annot=True, cmap = 'viridis')
###############################################
num=df.to_numpy()
x=df.iloc[1]['JobTitle']    #iloc for 1st row
rows=df.shape[0]
average_age=df['Age'].sum()
average_age=average_age/rows

for i in range(0,rows):
  try:
    missing_abs=df.iloc[i]['AbsentHours']
  except:
    break
  flag=0
  if int(missing_abs)==0:
    df = df.drop(df.index[i])
    flag=1
  if float(df.iloc[i]['Age'])>float((average_age+(average_age*0.3))) and flag==0 or float(df.iloc[i]['Age'])<float((average_age-(average_age*0.3))) and flag==0:      
  #it is finding and deleting the values that going above the upper bound and below the lower bound
    df = df.drop(df.index[i])

print(df.to_string())
# Out:
# (500, 13)
# <bound method DataFrame.info of      EmployeeNumber    Surname GivenName Gender             City JobTitle  \
# 0                 1  Gutierrez     Molly      F          Burnaby    Baker
# 1                 2   Hardwick   Stephen      M        Courtenay    Baker
# 2                 3    Delgado   Chester      M         Richmond    Baker
# 3                 4      Simon     Irene      F         Victoria    Baker
# 4                 5   Delvalle    Edward      M  New Westminster    Baker
# ..              ...        ...       ...    ...              ...      ...
# 495             496      Green      Anna      F  New Westminster  Cashier
# 496             497     Nevitt   Phillip      M           D'arcy    Baker
# 497             498      Troup    Martha      F          Burnaby    Baker
# 498             499       Ross      Eric      M           Surrey    Baker
# 499             500     Farley     Jerry      M         Winfield    Baker
#
# ...
